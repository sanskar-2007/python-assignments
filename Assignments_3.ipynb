# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskar-2007/python-assignments/blob/main/Assignments_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment No: 03

# 1) WAP to find greatest of 3 numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Greatest number is:", a)
elif b >= a and b >= c:
    print("Greatest number is:", b)
else:
    print("Greatest number is:", c)


# 2) WAP to check whether a number is odd or even
num = int(input("\nEnter a number: "))

if num % 2 == 0:
    print("Number is Even")
else:
    print("Number is Odd")


# 3) WAP to check whether a character is uppercase or lowercase
ch = input("\nEnter a character: ")

if ch.isalpha():
    if ch.isupper():
        print("Uppercase Alphabet")
    else:
        print("Lowercase Alphabet")
else:
    print("Not an alphabet")


# 4) WAP to check whether input is number or character
ch = input("\nEnter any input: ")

if ch.isdigit():
    print("It is a number")
elif ch.isalpha():
    print("It is a character")
else:
    print("It is a special symbol")
# Out:
# Enter first number: 7
# Enter second number: 8
# Enter third number: 9
# Greatest number is: 9
#
# Enter a number: 77
# Number is Odd
#
# Enter a character: Sanskar
# Not an alphabet
#
# Enter any input: Sanskar
# It is a character

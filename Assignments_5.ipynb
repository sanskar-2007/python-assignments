# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskar-2007/python-assignments/blob/main/Assignments_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#assignment no.5
#1 to calculate length of the string
my_string = "Hello"
length = len(my_string)
print(length)


#2 to make the string from 1st and last two characters from given string
text = "Programming"
# Slice first two [0:2] and last two [-2:]
result = text[:2] + text[-2:]
print(result)  # Output: Prng


#3 to concatenate two strings
str1 = "Hello"
str2 = "World"

# Join them with a space
full_string = str1 + " " + str2
print(full_string)  # Output: Hello World
# Out:
# 5
# Prng
# Hello World
